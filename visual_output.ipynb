# %%
import matplotlib.pyplot as plt
from utils import decode_predictions
import tensorflow as tf
import numpy as np
import cv2
from functools import partial
from vgg import forward, conv_filter
from vgg_deconv import backward
from numba import cuda
from main import load_images, vis_layer
# %matplotlib inline
import multiprocessing as mp
from multiprocessing import Process
mp.set_start_method('forkserver', force = True)
gpu = tf.config.experimental.get_visible_devices("GPU")[0]
tf.config.experimental.set_memory_growth(gpu, enable = True)

# %%
print(mp.get_start_method())
# Out:
# forkserver

# %%
img_path = './data/cat.jpg'
img = load_images(img_path)
conv = forward
deconv = backward

# %%
img = cv2.imread(img_path)
img = cv2.resize(img, (224, 224))
img = img[..., ::-1]
plt.imshow(img)

# %%
img = img[np.newaxis,...]
conv, _ = forward(img, layer = 1)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 2)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 3)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 4)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 5)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 8)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 10)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 12)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])

# %%
conv, _ = forward(img, layer = 13)
conv_ = conv[0]
fig, ax = plt.subplots(8,8, figsize = (14, 14))
for i in range(64):
    _ = ax[i//8, i%8].imshow(conv_[..., i])
